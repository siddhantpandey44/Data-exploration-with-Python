# %% [markdown]
# # Data Exploration Using Python
# In this project, the purpose is to perform exploratory data analysis and data cleaning on Movies dataset taken from Kaggle.

# %%
#import Libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
#plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %% [markdown]
# *Read the dataset into a dataframe*

# %%
df = pd.read_csv('movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# *Data Cleaning*

# %%
for col in df.columns:
    missing = np.mean(df[col].isnull())
    print('{} {}'.format(col,missing*100))
# Out:
# name 0.0
# rating 1.004173187271779
# genre 0.0
# year 0.0
# released 0.02608242044861763
# score 0.03912363067292645
# votes 0.03912363067292645
# director 0.0
# writer 0.03912363067292645
# star 0.013041210224308816
# country 0.03912363067292645
# budget 28.31246739697444
# gross 2.464788732394366
# company 0.2217005738132499
# runtime 0.05216484089723526

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df.dropna(subset='budget',inplace=True)

# %%
df.dropna(subset='gross',inplace=True)

# %%
for col in df.columns:
    missing = np.mean(df[col].isnull())
    print('{} {}'.format(col,missing*100))
# Out:
# name 0.0
# rating 0.22075055187637968
# genre 0.0
# year 0.0
# released 0.0
# score 0.0
# votes 0.0
# director 0.0
# writer 0.0
# star 0.0
# country 0.01839587932303164
# budget 0.0
# gross 0.0
# company 0.03679175864606328
# runtime 0.01839587932303164

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df['budget'] = df['budget'].astype('int64')

# %%
df['gross'] = df['gross'].astype('int64')

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %% [markdown]
# Are there any outliers?

# %%
df.boxplot(column=['gross'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['budget'])
# Out:
# <AxesSubplot:>

# %%
df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Order our Data a little bit to see

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 2417                                    Madadayo        NaN   Drama  1993
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes          director  \
# ...

# %% [markdown]
# **Data Analysis and Correlation**

# %%
plt.scatter('gross','budget',data=df)
plt.xlabel('Gross')
plt.ylabel('Budget')
plt.title('Gross vs Budget')

plt.legend

plt.show()

# %%
sns.regplot('gross','budget',data=df,scatter_kws={'color':'red'},line_kws={'color':'blue'})
# Out:
# C:\Users\siddh\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gross', ylabel='budget'>

# %%
df.corr(method='pearson') # pearson, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.055174  0.205758  0.327781  0.274264  0.074203
# score    0.055174  1.000000  0.473809  0.071792  0.222143  0.414580
# votes    0.205758  0.473809  1.000000  0.440021  0.614904  0.352437
# budget   0.327781  0.071792  0.440021  1.000000  0.740395  0.318595
# gross    0.274264  0.222143  0.614904  0.740395  1.000000  0.275596
# runtime  0.074203  0.414580  0.352437  0.318595  0.275596  1.000000

# %%
df.corr(method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.038391  0.295884  0.220991  0.239313  0.064106
# score    0.038391  1.000000  0.350111 -0.006518  0.124715  0.292872
# votes    0.295884  0.350111  1.000000  0.346228  0.553640  0.205616
# budget   0.220991 -0.006518  0.346228  1.000000  0.512637  0.230879
# gross    0.239313  0.124715  0.553640  0.512637  1.000000  0.176825
# runtime  0.064106  0.292872  0.205616  0.230879  0.176825  1.000000

# %%
df.corr(method='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056269  0.426571  0.313199  0.350679  0.094396
# score    0.056269  1.000000  0.495379 -0.010133  0.182857  0.413040
# votes    0.426571  0.495379  1.000000  0.493404  0.745815  0.300959
# budget   0.313199 -0.010133  0.493404  1.000000  0.693670  0.330276
# gross    0.350679  0.182857  0.745815  0.693670  1.000000  0.257121
# runtime  0.094396  0.413040  0.300959  0.330276  0.257121  1.000000

# %%
Correlation = df.corr(method='pearson')
sns.heatmap(Correlation, annot=True,cmap='RdYlGn')
plt.xlabel('Movies Feratures')
plt.ylabel('Movies Feratures')

plt.title('Correlation Matrix among numerical features')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix among numerical features')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df_numerized = df

# %%
for col in df_numerized.columns:
    if (df_numerized[col].dtype == 'object'):
        df_numerized[col] = df_numerized[col].astype('category')
    
df_numerized
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df_numerized.dtypes
# Out:
# name        category
# rating      category
# genre       category
# year           int64
# released    category
# score        float64
# votes        float64
# director    category
# writer      category
# star        category
# country     category
# budget         int64
# gross          int64
# company     category
# runtime      float64
# dtype: object

# %%
for col in df_numerized.columns:
    if (df_numerized[col].dtype == 'category'):
        df_numerized[col] = df_numerized[col].cat.codes
    
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     4706       6      6  1980      1308    8.4   927000.0      1800    2841
# 1     3943       6      1  1980      1131    5.8    65000.0      1581    1160
# 2     3654       4      0  1980      1363    8.7  1200000.0       759    1822
# 3      205       4      4  1980      1131    7.7   221000.0       891    1416
# 4      734       6      4  1980      1174    7.3   108000.0       721     352
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7648   416       6      0  2020       907    6.6   140000.0        17    2397
# 7649  3569       4      0  2020       715    6.5   102000.0       854    2316
# 7650  1156       4      1  2020       907    5.6    53000.0      1814    2836
# 7651  3992       4      1  2020       760    6.8    42000.0       296    2096
# 7652  4104       3      0  2020       371    6.8     3700.0       748    1186
#
# ...

# %%
Correlation = df_numerized.corr(method='pearson')
sns.heatmap(Correlation, annot=True)
plt.xlabel('Movies Feratures')
plt.ylabel('Movies Feratures')

plt.title('Correlation Matrix among numerical features')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix among numerical features')

# %%
corr_matrix = df_numerized.corr()
corr_pairs = corr_matrix.unstack()

corr_pairs
# Out:
# name     name        1.000000
#          rating     -0.023013
#          genre       0.009617
#          year        0.024435
#          released   -0.005896
#                        ...
# runtime  country    -0.033554
#          budget      0.318595
#          gross       0.275596
#          company     0.038752
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre    budget    -0.368900
# budget   genre     -0.368900
# genre    gross     -0.244380
# gross    genre     -0.244380
# rating   budget    -0.186892
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]

high_corr
# Out:
# gross     votes       0.614904
# votes     gross       0.614904
# budget    gross       0.740395
# gross     budget      0.740395
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
df = pd.read_csv('movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.sort_values(by=['gross'],ascending=False).head(5)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
df_top5 = df.sort_values(by=['gross'],ascending=False).head(5)


sns.relplot('name','gross',data=df_top5,size='name',sizes=(500,1500),hue='name',height=6, aspect=12/6)

plt.xlabel=('Movie')
plt.ylabel=('Gross Earnings')
plt.title('Top 5 Movies with highest gross earnings')
#plt.style.use('fast')

plt.show()
# Out:
# C:\Users\siddh\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_ratings = df.sort_values(by=['score'],ascending=False).head(10)

# %%
df_ratings
# Out:
#                                                    name rating      genre  \
# 2443                           The Shawshank Redemption      R      Drama
# 5243                                    The Dark Knight  PG-13     Action
# 2247                                   Schindler's List      R  Biography
# 2444                                       Pulp Fiction      R      Crime
# 4245      The Lord of the Rings: The Return of the King  PG-13     Action
# 5643                                          Inception  PG-13     Action
# 3845  The Lord of the Rings: The Fellowship of the Ring  PG-13     Action
# 2445                                       Forrest Gump  PG-13      Drama
# 3444                                         Fight Club      R      Drama
# 4048              The Lord of the Rings: The Two Towers  PG-13     Action
#
#       year                           released  score      votes  \
# 2443  1994   October 14, 1994 (United States)    9.3  2400000.0
# ...

# %%
import squarify

colors = ["#6b2e32","#954c50","#c1928e","#e9c8c4","#f3e8cd","#dcdbc9","#aac5b4","#738972","#40544b","#4f6069"]
squarify.plot(sizes=df_ratings['score'], label=df_ratings['name'], alpha=0.6,color=colors).set(title='Treemap for Movies with highest IMDB ratings')
plt.show()

# %%
sns.stripplot(x="rating", y="gross", data=df)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='gross'>
